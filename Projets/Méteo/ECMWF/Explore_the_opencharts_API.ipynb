# %% [markdown]
# # Explore the OpenCharts API
#
# In this notebook you will find out what information can be obtained from the OpenCharts API and the basics on how to download an image.
#
# ## List all the available products
#
# The common part of all the links to download open charts in **api_url** variable:

# %%
api_url = "https://charts.ecmwf.int/opencharts-api/v1/"

# %% [markdown]
# And the link to download the information about all the layers can be constructed like this.
# Let's print it:

# %%
print('{}products/'.format(api_url))
# Out:
# https://charts.ecmwf.int/opencharts-api/v1/products/

# %% [markdown]
# Let's download it and print here.

# %%
import requests

result =requests.get('{}products/'.format(api_url))

all_data = result.json()

# %% [markdown]
# This has returned us a big json structure with the definitions of all the products from OpenCharts.
# If you click on the printed link you will get the same structure in the new tab.
# Let's print first 5 elements of the list.

# %%
all_data[:5]
# Out:
# [{'api-documentation': 'https://charts.ecmwf.int/opencharts-api/v1/swagger-ui/?product=medium-mslp-wind850&package=opencharts',
#   'schema-url': 'https://charts.ecmwf.int/opencharts-api/v1/schema/?product=medium-mslp-wind850&package=openchart',
#   'name': 'medium-mslp-wind850',
#   'product-url': 'https://charts.ecmwf.int/opencharts-api/v1/products/medium-mslp-wind850/',
#   'title': 'Mean sea level pressure and 850 hPa wind speed'},
#  {'api-documentation': 'https://charts.ecmwf.int/opencharts-api/v1/swagger-ui/?product=medium-z500-t850&package=opencharts',
#   'schema-url': 'https://charts.ecmwf.int/opencharts-api/v1/schema/?product=medium-z500-t850&package=openchart',
#   'name': 'medium-z500-t850',
#   'product-url': 'https://charts.ecmwf.int/opencharts-api/v1/products/medium-z500-t850/',
#   'title': '500 hPa geopotential height and 850 hPa\xa0temperature'},
#  {'api-documentation': 'https://charts.ecmwf.int/opencharts-api/v1/swagger-ui/?product=medium-2mt-wind30&package=opencharts',
#   'schema-url': 'https://charts.ecmwf.int/opencharts-api/v1/schema/?product=medium-2mt-wind30&package=openchart',
#   'name': 'medium-2mt-wind30',
#   'product-url': 'https://charts.ecmwf.int/opencharts-api/v1/products/medium-2mt-wind30/',
#   'title': '2 m temperature and 30 m wind'},
#  {'api-documentation': 'https://charts.ecmwf.int/opencharts-api/v1/swagger-ui/?product=medium-wind-100m&package=opencharts',
#   'schema-url': 'https://charts.ecmwf.int/opencharts-api/v1/schema/?product=medium-wind-100m&package=openchart',
#   'name': 'medium-wind-100m',
#   'product-url': 'https://charts.ecmwf.int/opencharts-api/v1/products/medium-wind-100m/',
#   'title': '100 m wind and mean sea level pressure'},
#  {'api-documentation': 'https://charts.ecmwf.int/opencharts-api/v1/swagger-ui/?product=medium-mslp-wind200&package=opencharts',
#   'schema-url': 'https://charts.ecmwf.int/opencharts-api/v1/schema/?product=medium-mslp-wind200&package=openchart',
#   'name': 'medium-mslp-wind200',
#   'product-url': 'https://charts.ecmwf.int/opencharts-api/v1/products/medium-mslp-wind200/',
#   'title': 'Mean sea level pressure and 200 hPa wind'}]

# %% [markdown]
# To see all the product names, we can list them all:

# %%
products = []
for product in all_data:
    products.append(product["name"])
print (products)
# Out:
# ['medium-mslp-wind850', 'medium-z500-t850', 'medium-2mt-wind30', 'medium-wind-100m', 'medium-mslp-wind200', 'medium-mslp-rain', 'medium-clouds', 'medium-rv-div-uv', 'medium-simulated-ir', 'medium-simulated-wv', 'medium-simulated-wbpt', 'medium-simulated-wv-wbpt', 'medium-t-z', 'medium-2t-wind', 'medium-uv-z', 'medium-uv-rh', 'medium-thickness-mslp', 'medium-indices', 'medium-cape-cin', 'medium-precipitation-type', 'medium-tcw', 'medium-sund_interval', 'medium-rain-acc', 'medium-snowfall', 'medium-rain-rate', 'medium-frz-rain', 'medium-rain-detailed', 'medium-lightning', 'medium-2t-dp', 'medium-bulk-shear', 'medium-shear', 'medium-wind-10wg', 'medium-wind-10m', 'medium-cloud-parameters', 'medium-visibility', 'medium-zero-level', 'medium-specific-humidity', 'medium-swh-mwd', 'medium-tssh-mwd', 'medium-wwsh-mwd', 'medium-mwp-mwd', 'medium-mwpts-mwd', 'medium-mwpww-mwd', 'medium-pv', 'medium-divergence', 'medium-vorticity', 'medium-wave-period', 'medium-wave-energy-flux', 'medium-albedo', 'medium-orography', 'medium-lai', 'medium-snow-sic', 'w_sst', 'w_soil_moisture', 'pincr', 'medium-mslp-mean-spread', 'plot_ensm_essential', 'medium-2t-mean-spread', 'medium-mslp-spread', 'medium-10ws-mean-spread', 'medium-100ws-mean-spread', 'medium-sst-mean-spread', 'medium-t500-mean-spread', 'medium-z300-mean-spread', 'medium-t10-mean-spread', 'medium-multi-efi', 'efi2web_2t', 'efi2web_2tmin', 'efi2web_2tmax', 'efi2web_10fg', 'efi2web_10ff', 'efi2web_tp', 'efi2web_hsttmax', 'efi2web_sf', 'efi2web_cape', 'efi2web_capeshear', 'efi2web_wvf', 'medium-trajectories', 'pb_tpr', 'medium-ens-fzrain', 'medium-point-rain-prob', 'medium-ens-tp', 'medium-ens-snow', 'medium-ens-rain-rate', 'medium-ens-visibility', 'medium-ens-mn2t', 'medium-ens-lightning', 'medium-ens-mx2t', 'medium-ens-2tdew', 'medium-ens-cape-shear', 'medium-ens-cape', 'medium-ens-wind', 'medium-2t-probability', 'medium-ens-ptype', 'medium-10m-probability', 'medium-wg-probability', 'medium-tp-probability', 'medium-swh-probability', 'medium-mwp-probability', 'medium-2t-long-probability', 'medium-tp-long-probability', 'medium-wg-long-probability', 'medium-swh-long-probability', 'medium-mwp-long-probability', 'medium-ens-tp-2t', 'medium-ens-tp-ws', 'medium-ens-sf-wg', 'medium-ens-wave-ws', 'medium-2t-anomaly', 'medium-tp-anomaly', 'medium-ws-anomaly', 'medium-sf-anomaly', 'opencharts_meteogram', 'visibility_meteogram_aviation', 'visibility_meteogram_public', 'opencharts_ptype_meteogram', 'visibility_meteogram', 'opencharts_efi-cdf-meteogram', 'opencharts_vertical-profile-meteogram', 'opencharts_extended_meteogram', 'aifs_medium-mslp-wind850', 'fourcast_medium-mslp-wind850', 'graphcast_medium-mslp-wind850', 'pangu_medium-mslp-wind850', 'aifs_medium-z500-t850', 'fourcast_medium-z500-t850', 'graphcast_medium-z500-t850', 'pangu_medium-z500-t850', 'aifs_medium-mslp-wind200', 'fourcast_medium-mslp-wind200', 'graphcast_medium-mslp-wind200', 'pangu_medium-mslp-wind200', 'graphcast_medium-mslp-rain', 'aifs_medium-t-z', 'fourcast_medium-t-z', 'graphcast_medium-t-z', 'pangu_medium-t-z', 'aifs_medium-2t-wind', 'fourcast_medium-2t-wind', 'graphcast_medium-2t-wind', 'pangu_medium-2t-wind', 'aifs_medium-uv-z', 'fourcast_medium-uv-z', 'graphcast_medium-uv-z', 'pangu_medium-uv-z', 'fourcast_medium-tcw', 'graphcast_medium-rain-acc', 'cluster_plot_legA', 'enplot', 'medium-tc-genesis', 'cyclone', 'plwww_m_hr_ccafreach_ts_hs', 'plwww_m_eps_t850crpssreach_ts', 'plwww_m_eps_tpcrpssreach_ts', 'plwww_m_hr_seepsreach_ts_hs', 'plwww_m_efi_roc_hs', 'plwww_y_tc', 'plwww_m_eps_2tcrpsfracv_ts_hs', 'plwww_y_enfh_2trpssd_ts_hs', 'plwww_m_hr_ccafreachmulti_ts', 'plwww_m_hr_ccaf_adrian_ts', 'plwww_m_hr_wp_ts', 'plwww_m_hr_ccafreach_ts', 'plwww_d_hr_cfpf_ts', 'plwww_m_hr_seepsreach_ts', 'plwww_m_eps_wp_brier_ts', 'plwww_m_efi_roc', 'plwww_m_eps_2tcrpsfracv_ts', 'plwww_y_enfh_2trpssd_ts', 'plwww_w_other_ts_mslp', 'plwww_w_other_ts_upperair', 'plwww_3m_ens_tigge_spreldiag', 'plwww_3m_ens_tigge_upper_mean', 'plwww_3m_ens_tigge_wp_ ...

# %% [markdown]
# ## Individual products
#
# All previous exploration was on the list of all products.
#
# However, in order to get the image we need to get the data from the API for the individual product.

# %%
product = 'medium-2mt-wind30'
get = '{}products/{}/'.format(api_url, product)

result = requests.get(get)

data = result.json()

# %%
data
# Out:
# {'meta': {'terms-and-conditions': {'href': 'https://apps.ecmwf.int/datasets/licences/general/'},
#   'license': 'CC-BY-4.0',
#   'copyright': '2021 European Centre for Medium-Range Weather Forecasts'},
#  'data': {'link': {'href': 'https://charts.ecmwf.int/content/20221019091836-a97cc57c1290ff838418ca0afe4a5769eacd52b3.png',
#    'type': 'image/png'},
#   'attributes': {'description': 'Base time: Wed 19 Oct 2022 00 UTC Valid time: Wed 19 Oct 2022 00 UTC (+0h) Area : Europe',
#    'name': 'medium-2mt-wind30',
#    'title': '2 m temperature and 30 m wind'},
#   'type': 'graphical_product'},
#  'tracker': 'tracker-340b3a8fc6a74c0fad7ee641bd3669b8',
#  'uid': ''}

# %% [markdown]
# We can now see that the link to the png image of the procut is under **data['data']['link']['href']**

# %%
data["data"]["link"]["href"]
# Out:
# 'https://charts.ecmwf.int/content/20231213103732-3ddf232832b03923e6d373be8b92a782254f2bbe.png'

# %% [markdown]
# Finally we can see the image in the link using display fucntion.

# %%
from IPython import display
display.Image(data["data"]["link"]["href"])

# %% [markdown]
# This has given us the image of the default time and area for this product.
# Please check the other notebooks in this series to learn how to download products for a particular date and step and for specific area, or how to get the image as pdf file.
