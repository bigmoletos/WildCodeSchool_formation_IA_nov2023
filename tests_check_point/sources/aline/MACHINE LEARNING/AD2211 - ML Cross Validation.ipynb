# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import cross_val_score

# %%
link = "https://web.stanford.edu/class/archive/cs/cs109/cs109.1166/stuff/titanic.csv"
df_titanic = pd.read_csv(link)
df_titanic.head()
# Out:
#    Survived  Pclass  ... Parents/Children Aboard     Fare
# 0         0       3  ...                       0   7.2500
# 1         1       1  ...                       0  71.2833
# 2         1       3  ...                       0   7.9250
# 3         1       1  ...                       0  53.1000
# 4         0       3  ...                       0   8.0500
#
# [5 rows x 8 columns]

# %% [markdown]
# Data prep

# %%
#On transforme les valeurs de la colonne 'survived' pour plus de clareté : 1 = Survived , 0 = Dead
df_titanic['Survived'] = df_titanic['Survived'].apply(lambda x: "Survived" if x == 1 else "Dead")

# %%
#On factorise la colonne sex
df_titanic['Sex'] = df_titanic['Sex'].factorize()[0]

# %% [markdown]
# Tu vas effectuer une classification supervisée sur la colonne "survived", en effectuant un traintestsplit (sans fixer le random_state), puis un classifieur de ton choix (knn, decision tree, régression logistique, etc...). Tu dois faire apparaitre clairement l'accuracy score du jeu d'entrainement et celui du jeu de test.

# %%
X = df_titanic[['Pclass' ,'Sex',	'Age' ,	'Siblings/Spouses Aboard' ,	'Parents/Children Aboard' ,	'Fare']]
y = df_titanic['Survived']

X_train, X_test, y_train, y_test = train_test_split(X, y)

model = LogisticRegression().fit(X_train,y_train)

print("\nScore for the Train dataset :", model.score(X_train, y_train))
print("Score for the Test dataset :", model.score(X_test, y_test))
# Out:
# Score for the Train dataset : 0.8
# Score for the Test dataset : 0.8153153153153153

# %% [markdown]
# Dans un nouveau bloc de code, tu vas effectuer exactement la même étape que précédemment. Comme tu n'as pas fixé le random_state, le score devrait être différent.

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y)

model = LogisticRegression().fit(X_train,y_train)

print("\nScore for the Train dataset :", model.score(X_train, y_train))
print("Score for the Test dataset :", model.score(X_test, y_test))
# Out:
# Score for the Train dataset : 0.8105263157894737
# Score for the Test dataset : 0.8108108108108109

# %%
#Effectivement les scores ne sont pas les mêmes, mais l'écart est très faible. Testons avec la cross validation...

# %% [markdown]
# Avec ce même classifier, tu vas lancer une crossvalidation avec un découpage en 6 parties. La CrossValidation renforce-t-elle votre confiance dans cette prédiction ?

# %%
scoresCV = cross_val_score(LogisticRegression(), X, y, cv = 6 )
scoresCV
# Out:
# array([0.77702703, 0.80405405, 0.79054054, 0.78378378, 0.7972973 ,
#        0.81632653])

# %%
#L'écart entre les scores reste faible et ce sont plutôt de bons scores, on peut donc avoir une assez bonne confiance en ce modèle

# %% [markdown]
# Tu vas calculer la moyenne et l'écart-type des 6 scores obtenus.

# %%
scoresCV.mean()
# Out:
# 0.7948382055524913

# %%
scoresCV.std()
# Out:
# 0.01297841384343086

# %%
#Le calcul de l'écart type confirme le faible écart entre les scores. On peut donc considérer que le score de notre modèle est environ 0,79
