# %% [markdown]
# # Imports

# %%
from datetime import datetime
from datetime import timedelta
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# # You have to convert each string variable into datetime objects

# %%
var1 = '2018-01-04'
print(type(var1))
print(var1)
# Out:
# <class 'str'>
# 2018-01-04

# %%
# It's up to you :
var1Date = datetime.strptime(var1, '%Y-%m-%d')
print(type(var1Date))
print(var1Date)
# Out:
# <class 'datetime.datetime'>
# 2018-01-04 00:00:00

# %%
var2 = '14/02/2019'
# It's up to you :
var2Date = datetime.strptime(var2, '%d/%m/%Y')
print(type(var2Date))
print(var2Date)
# Out:
# <class 'datetime.datetime'>
# 2019-02-14 00:00:00

# %%
var3 = '14 03 20'
# It's up to you :
var3Date = datetime.strptime(var3, '%d %m %y')
print(type(var3Date))
print(var3Date)
# Out:
# <class 'datetime.datetime'>
# 2020-03-14 00:00:00

# %%
var4 = '14/02/2019 21:30'
# It's up to you :
var4Date = datetime.strptime(var4, '%d/%m/%Y %H:%M')
print(type(var4Date))
print(var4Date.strftime("%d/%m/%Y %H:%M"))
# Out:
# <class 'datetime.datetime'>
# 14/02/2019 21:30

# %%
var5 = '2018-01-04 at 18 hours and 48 min'
# It's up to you :
var5Date = datetime.strptime(var5, '%Y-%m-%d at %H hours and %M min')
print(type(var5Date))
print(var5Date.strftime("%Y-%m-%d"), "at", var5Date.strftime("%H"), "hours and", var5Date.strftime ("%M"), "min")
# Out:
# <class 'datetime.datetime'>
# 2018-01-04 at 18 hours and 48 min

# %% [markdown]
# # You have to convert a datetime object into string with precise format

# %%
var_date = datetime.strptime('2020-02-15 20:05', '%Y-%m-%d %H:%M')
print(var_date)
# Out:
# 2020-02-15 20:05:00

# %%
# We would like to print this format : 15/02/2020

datetime.strftime(var_date, '%d/%m/%Y')
# Out:
# '15/02/2020'

# %%
# We would like to print this format : 15-02-2020

datetime.strftime(var_date, '%d-%m-%Y')
# Out:
# '15-02-2020'

# %%
# We would like to print this format : 15/02

datetime.strftime(var_date, '%d/%m')
# Out:
# '15/02'

# %%
# We would like to print this format : 2020-02
datetime.strftime(var_date, '%Y-%m')
# Out:
# '2020-02'

# %%
# We would like to print this format : 2020-02-15 at 20:05

datetime.strftime(var_date, '%Y-%m-%d at %H:%M')
# Out:
# '2020-02-15 at 20:05'

# %% [markdown]
# # Your mission is to determine which date it was / it will be

# %%
# what day will it be in 7 weeks ?
print(datetime.now() + timedelta(weeks=7))
# Out:
# 2021-12-15 08:23:09.466313

# %%
# what day will it be in 7 days ?
print(datetime.now() + timedelta(days=7))
# Out:
# 2021-11-03 08:23:09.475506

# %%
# what day will it be in 72 hours ?
print(datetime.now() + timedelta(hours=72))
# Out:
# 2021-10-30 08:23:09.483679

# %%
# what date was 30 days ago ?
print(datetime.now() + timedelta(days=-30))
# Out:
# 2021-09-27 08:23:09.495633

# %%
# what date was 30 weeks ago ?
print(datetime.now() + timedelta(weeks=-30))
# Out:
# 2021-03-31 08:23:09.505965

# %% [markdown]
# # With Pandas
# "DATE" column has only string values. On a chart, the X-axis is not well displayed.

# %%
# Just execute the code below:
df = pd.read_csv("https://raw.githubusercontent.com/murpi/wilddata/master/quests/weather2019.csv")
plt.scatter(x = df['DATE'], 
            y = df['MAX_TEMPERATURE_C'])
plt.show()

# %%
# Convert "DATE" column into a datetime format, then display the same chart. Are ticks on X-axis better printed ?

plt.scatter(x = pd.to_datetime(df['DATE']), 
            y = df['MAX_TEMPERATURE_C'])
plt.show()

# %%
pd.to_datetime(df['DATE'])
# Out:
# 0     2019-01-01
# 1     2019-01-02
# 2     2019-01-03
# 3     2019-01-04
# 4     2019-01-05
#          ...
# 360   2019-12-27
# 361   2019-12-28
# 362   2019-12-29
# 363   2019-12-30
# 364   2019-12-31
# Name: DATE, Length: 365, dtype: datetime64[ns]

# %%
# Display only rows for the month of June
june = (df['DATE'] >= '2019-06-01') & (df['DATE'] <= '2019-06-31')
plt.scatter(x = pd.to_datetime(df['DATE']).loc[june], 
            y = df['MAX_TEMPERATURE_C'].loc[june])
plt.xticks(rotation = 45) 
plt.show()
