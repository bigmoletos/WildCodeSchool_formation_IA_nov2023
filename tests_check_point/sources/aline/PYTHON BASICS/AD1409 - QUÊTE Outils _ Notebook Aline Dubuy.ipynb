# %% [markdown]
# #### **Version de Python**

# %%
import sys
print (sys.version)
# Out:
# 3.7.11 (default, Jul  3 2021, 18:01:19)
# [GCC 7.5.0]

# %% [markdown]
# #### **Résultat de 38+4**

# %%
var1 = 38
var2 = 4
var1 + var2
# Out:
# 42

# %% [markdown]
# #### **Formule mathématique**

# %% [markdown]
# $x= \frac{-b \pm \sqrt{b^2-4ac}}{2a}$

# %% [markdown]
# #### **Vidéo Youtube**

# %% [markdown]
# <a href="http://www.youtube.com/watch?feature=player_embedded&v=inN8seMm7UI
# " target="_blank"><img src="http://img.youtube.com/vi/inN8seMm7UI/0.jpg"
# alt="IMAGE ALT TEXT HERE" width="240" height="180" border="10" /></a>
