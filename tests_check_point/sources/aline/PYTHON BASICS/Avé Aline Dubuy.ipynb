# %%
def codeCesar(message):
  message = message.lower()
  messageDecrypte = ""
  alphabet = "abcdefghijklmnopqrstuvwxyz"
  code = -7
  for char in message:   
      if char == " ":
        messageDecrypte += " "
      else: 
        messageDecrypte += alphabet[alphabet.index(char)-7]
  return messageDecrypte

codeCesar("Dlzo iyv ab jvklz lu wfaovu thpualuhua")
# Out:
# 'wesh bro tu codes en python maintenant'
