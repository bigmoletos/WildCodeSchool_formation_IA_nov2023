# %% [markdown]
# # Mission 1
#
# Create a script that takes a list and displays only the elements (and their position) that have positions that are even (0, 2, 4, 6...).
#
# Example list = ["a", "b", "c", "d", "e"], the script should return :
# - a position 0
# - c position 2
# - e position 4

# %%
input_string = input("Enter a list element separated by space ")
liste  = input_string.split()

for index in range(0,len(liste),2):
  print(liste[index], "position", index)
# Out:
# Enter a list element separated by space a b c d e f g
# a position 0
# c position 2
# e position 4
# g position 6

# %% [markdown]
# # Mission 2
#
# We have a list. Create a script to replace the value of an element with another simply by indicating its position.
#
# For example, we want to change the value of the third element of the list below:

# %%
example = ['hello', 'good morning', 'bye bye', 'have a good day']

print ("Indique la position de l'élément que tu souhaites changer")
position = int(input())
print ("Indique par quoi tu le veux changer")
changedElement = input()

example[position-1] = changedElement
print(example)
# Out:
# Indique la position de l'élément que tu souhaites changer
# 3
# Indique par quoi tu le veux changer
# good bye
# ['hello', 'good morning', 'good bye', 'have a good day']

# %% [markdown]
# # Mission 3
#
# Create a list, then add an element to the end of a list and remove the first element so that the list stays the same size.

# %%
input_string = input("Enter a list element separated by space ")
liste  = input_string.split()
elementToAdd = input("Add an element ")

liste.append(elementToAdd)
liste.pop(0)

print(liste)
# Out:
# Enter a list element separated by space ABC DEF GHI
# Add an element JKL
# ['DEF', 'GHI', 'JKL']

# %% [markdown]
# # Mission 4
#
# Create a script that does the same thing as the insert method, but at a random position.

# %%
import random
liste = ["a","a","a","a","a","a"]
liste.insert(random.randrange(len(liste)), "b")
print(liste)
# Out:
# ['a', 'a', 'a', 'b', 'a', 'a', 'a']

# %% [markdown]
# # Mission 5
#
# Create a script that does the same thing as the pop method for a list containing only characters. The difference is that this function displays a message indicating the number of characters that are identical to the deleted character and still remain in the list. In other words, if there were 3 "b" in the list, and one has just been deleted by your function, the script will display "there are still 2 letters b".

# %%
input_string = input("Enter a list of characters separated by space ")
liste  = input_string.split()
print ("indicate a position to delete between 1 and", len(liste))
position = int(input())-1

letter = liste.pop(position)

print("there are still", liste.count(letter),"letters", letter)
# Out:
# Enter a list of characters separated by space A A A B B B
# indicate a position to delete between 1 and 6
# 5
# there are still 2 letters B

# %% [markdown]
# # Mission 6
#
# Create a script with 3 lists, and indicates the two that are "closest". That is to say, the two that have the most elements in common.

# %%
l1 = [1, 2, 3, 4, 5]
l2 = [9, 8, 7, 6, 5]
l3 = [2, 4, 6, 3, 8]
    
l1_l2 = len(set(l1) & set(l2))
l1_l3 = len(set(l1) & set(l3))
l3_l2 = len(set(l3) & set(l2))
closest = {'l1_l2' : l1_l2, 'l1_l3' : l1_l3, 'l3_l2' : l3_l2}
max(closest)
# Out:
# 'l3_l2'

# %% [markdown]
# # Mission 7
#
# Create a script that displays all the items in a list of int from smallest to the largest. In other words, a script that sorts the list from smallest to largest.

# %%
input_string = input("enter a list of integer separated with space ")
liste = input_string.split()
liste.sort()
print(liste)
# Out:
# enter a list of integer separated with space 2 34 56 23 78 2 89
# ['2', '2', '23', '34', '56', '78', '89']
