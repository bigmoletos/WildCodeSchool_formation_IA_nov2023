# %% [markdown]
# You must correct each of the scripts below **using exception handling** and **without modifying lists**.

# %% [markdown]
# Script number 1

# %%
list_integers = [1, 12, -45, 6, 27, 0, 24]
for i in list_integers:
  try :
    print(1/x)
  except NameError :
    print("you need to define x")
# Out:
# you need to define x
# you need to define x
# you need to define x
# you need to define x
# you need to define x
# you need to define x
# you need to define x

# %% [markdown]
# Script number 2

# %%
list_integers = [1, 12, -45, 6, 27, 24]
for i in range(10):
  try:
    print(1/list_integers[i])
  except IndexError :
    print("list_integers is shorter than the range")
# Out:
# 1.0
# 0.08333333333333333
# -0.022222222222222223
# 0.16666666666666666
# 0.037037037037037035
# 0.041666666666666664
# list_integers is shorter than the range
# list_integers is shorter than the range
# list_integers is shorter than the range
# list_integers is shorter than the range

# %% [markdown]
# Script number 3

# %%
list_integers = [1, 12, -45, 6, 27, 0, 24]
for i in range(10):
  try :
    print(1/list_integers[i])
  except :
    print("exception occured")
# Out:
# 1.0
# 0.08333333333333333
# -0.022222222222222223
# 0.16666666666666666
# 0.037037037037037035
# exception occured
# 0.041666666666666664
# exception occured
# exception occured
# exception occured

# %% [markdown]
# Script number 4

# %%
list_words = ['hello', 'good morning', 'GOOD Evening', 34, 'Bye' ]
for word in list_words:
  try :
    print(word.upper())
  except AttributeError :
    print("Be careful, there are not only strings in your list")
# Out:
# HELLO
# GOOD MORNING
# GOOD EVENING
# Be careful, there are not only strings in your list
# BYE
