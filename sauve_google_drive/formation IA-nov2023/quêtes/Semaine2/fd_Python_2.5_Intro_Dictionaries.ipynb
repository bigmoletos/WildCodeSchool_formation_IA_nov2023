# %% [markdown]
# # Mission 1

# %% [markdown]
# For each cell, execute the code and answer the question before moving on to the next.

# %%
people = {"Gontran": 23,
          "Jason": 42,
          "Ayoub": 27}


for i in people:
  print(i)
# Out:
# Gontran
# Jason
# Ayoub

# %% [markdown]
# 1. What does `i` correspond to?
# To answer, you must use the terms "keys" and "values".

# %% [markdown]
# Answer:
#
# key

# %%
for i in people.keys():
  print(i)
# Out:
# Gontran
# Jason
# Ayoub

# %%
for i in people.values():
  print(i)
# Out:
# 23
# 42
# 27

# %% [markdown]
# 2. What does `i` correspond to in the second last cell?
# What does `i` in the last cell correspond to?
# Why do you ask?

# %% [markdown]
# Answer:
#
# What does i correspond to in the second last cell?
#
# as the fisrt part it's a key
#
# What does i in the last cell correspond to?
#
# in the last cell i correspond to the value
#
# By default, without specification i correspond to the key

# %%
for i in people.items():
  print(i)
# Out:
# ('Gontran', 23)
# ('Jason', 42)
# ('Ayoub', 27)

# %% [markdown]
# 3. What is the type of object returned here called?

# %% [markdown]
# Answer:
#
# with .items we have got  tuples

# %%
for i, age in people.items():
  print(age)
# Out:
# 23
# 42
# 27

# %% [markdown]
# 4. Here I can recover the age of the people. How could I retrieve their names?

# %% [markdown]
# Answer:
#
# yes with print(i)

# %% [markdown]
# # Mission 2

# %%
people = {"Gontran": 23,
          "Jason": 42,
          "Ayoub": "27",
          "Léo": [10,20,30],
          "Rosario": {"Juan": 3,
                      "Camelia": 6}}


for i in people.values():
  print(type(i))
# Out:
# <class 'int'>
# <class 'int'>
# <class 'str'>
# <class 'list'>
# <class 'dict'>

# %% [markdown]
# 1. Does the above code allow me to confirm that I can have values of different types within a dictionary?

# %% [markdown]
# Answer:
#
# yes its possible to have value of different types within a dictionary

# %% [markdown]
# 2. Can I have keys of different types within a dictionary?

# %% [markdown]
# Answer:

# %%
people["Ayoub"] = int(people["Ayoub"])

for i in people.values():
  print(type(i))
# Out:
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'list'>
# <class 'dict'>

# %% [markdown]
# 3. What did the above code allow me to do?

# %% [markdown]
# Answer:
#
# this code allow me to cast the value of the key 'Ayoub' in a integer
#
# 'Ayoub': '27'  to  'Ayoub': 27

# %% [markdown]
# # Mission 3

# %%
groups = {"groupe_1": ["Lam", "Ghizlaine", "Khaled", "Florian"],
          "groupe_2": ["Lucile", "Mbaye", "Cécile", "Rohan"],
          "groupe_3": ["Agathe", "Charlotte", "Charles", "Maxime"],
          "groupe_4": ["Gaelle", "Linh", "Meral"]}


for i in groups.values():
  print(i)
# Out:
# ['Lam', 'Ghizlaine', 'Khaled', 'Florian']
# ['Lucile', 'Mbaye', 'Cécile', 'Rohan']
# ['Agathe', 'Charlotte', 'Charles', 'Maxime']
# ['Gaelle', 'Linh', 'Meral']

# %% [markdown]
# 1. What is the type of each value?
# How do I get into each list?

# %% [markdown]
# Answer:
#
# the type of each value is list
# if  Iam want each list I can be use groups.item() and not groups.values()
#
# Or you can do another loop for value in i:
# imbricated loop

# %%
for i in groups.values():
  for v in i:
    print(v)
# Out:
# Lam
# Ghizlaine
# Khaled
# Florian
# Lucile
# Mbaye
# Cécile
# Rohan
# Agathe
# Charlotte
# Charles
# Maxime
# Gaelle
# Linh
# Meral

# %% [markdown]
# 2. How did I get into each list?
# Take the time to explain your reasoning for answering this question.

# %% [markdown]
# Answer:
#
# On utilise dans ce cas une boucle imbriquée , donc une boucle dans une boucle
