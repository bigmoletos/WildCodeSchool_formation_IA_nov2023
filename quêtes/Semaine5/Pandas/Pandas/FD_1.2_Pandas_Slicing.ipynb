# %%
import pandas as pd
import numpy as np

# %% [markdown]
# # Méthode infos sur le dataframe

# %%
df.shape
# Out:
# (943, 4)

# %%
df.info()

# %%
df.describe()

# %%
df.size

# %%
df

# %%
df.head(10)
# Out:
#              country  beer_servings  spirit_servings  wine_servings  \
# 0        Afghanistan              0                0              0
# 1            Albania             89              132             54
# 2            Algeria             25                0             14
# 3            Andorra            245              138            312
# 4             Angola            217               57             45
# 5  Antigua & Barbuda            102              128             45
# 6          Argentina            193               25            221
# 7            Armenia             21              179             11
# 8          Australia            261               72            212
# 9            Austria            279               75            191
#
#    total_litres_of_pure_alcohol      continent
# 0                           0.0           Asia
# 1                           4.9         Europe
# 2                           0.7         Africa
# 3                          12.4         Europe
# 4                           5.9         Africa
# 5                           4.9  North America
# 6                           8.3  South America
# 7                           3.8         Europe
# 8                          10.4        Oceania
# 9                           9.7         Europe

# %% [markdown]
# # Mission 1
#
# Display the following information [for this dataset](https://raw.githubusercontent.com/justmarkham/pandas-videos/master/data/u.user).
# - The last 5 rows
# - The first 5 rows
# - The type of each column
#
# Note : start coding something by typing `pd.read_csv()` and explore the different options available, especially the `sep` parameter.

# %%
df=pd.read_csv("https://raw.githubusercontent.com/justmarkham/pandas-videos/master/data/u.user", sep="|", names=["age","genre","profession","dpt"], header=None)

# %% [markdown]
# # Mission 2
#
# Display the first 10 rows [in the following file](https://raw.githubusercontent.com/justmarkham/pandas-videos/master/data/drinks.csv)

# %%
df=pd.read_csv("https://raw.githubusercontent.com/justmarkham/pandas-videos/master/data/drinks.csv", header=0)
df.head(10)
# Out:
#              country  beer_servings  spirit_servings  wine_servings  \
# 0        Afghanistan              0                0              0
# 1            Albania             89              132             54
# 2            Algeria             25                0             14
# 3            Andorra            245              138            312
# 4             Angola            217               57             45
# 5  Antigua & Barbuda            102              128             45
# 6          Argentina            193               25            221
# 7            Armenia             21              179             11
# 8          Australia            261               72            212
# 9            Austria            279               75            191
#
#    total_litres_of_pure_alcohol      continent
# 0                           0.0           Asia
# 1                           4.9         Europe
# 2                           0.7         Africa
# 3                          12.4         Europe
# 4                           5.9         Africa
# 5                           4.9  North America
# 6                           8.3  South America
# 7                           3.8         Europe
# 8                          10.4        Oceania
# 9                           9.7         Europe

# %% [markdown]
# Set the "country" column as the index for the dataframe, using `set_index` method.

# %%
df.set_index("country", inplace=True)
df.head(15)
# Out:
#                    beer_servings  spirit_servings  wine_servings  \
# country
# Afghanistan                    0                0              0
# Albania                       89              132             54
# Algeria                       25                0             14
# Andorra                      245              138            312
# Angola                       217               57             45
# ...                          ...              ...            ...
# Tonga                         36               21              5
# Trinidad & Tobago            197              156              7
# Tunisia                       51                3             20
# Turkey                        51               22              7
# Turkmenistan                  19               71             32
#
#                    total_litres_of_pure_alcohol      continent
# country
# Afghanistan                                 0.0           Asia
# Albania                                     4.9         Europe
# Algeria                                     0.7         Africa
# Andorra                                    12.4         Europe
# Angola                                      5.9         Africa
# ...                                         ...            ...
# Tonga                                       1.1        Oceania
# Trinidad & Tobago                           6.4  North America
# Tunisia                                     1.3         Africa
# Turkey                                      1.4           Asia
# Turkmenistan                                2.2           Asia
#
# [178 rows x 5 columns]

# %% [markdown]
# # Mission 3
#
# Access the values of the row for **Zimbabwe** (use the index value)

# %%
df.loc["Zimbabwe"] # Ici on affiche toutes les lignes de la colonne "Amount"
# Out:
# beer_servings                       64
# spirit_servings                     18
# wine_servings                        4
# total_litres_of_pure_alcohol       4.7
# continent                       Africa
# Name: Zimbabwe, dtype: object

# %% [markdown]
# # Mision 4
#
# Display only the "continent" column value for the country **Zimbabwe**.

# %%
df.loc[ "Zimbabwe", "continent"] # Ici on affiche toutes les lignes de la colonne "Amount"
# Out:
# 'Africa'

# %%
# autre solution
df.loc[ "Zimbabwe"].iloc[-1]
# Out:
# 'Africa'

# %% [markdown]
# # Mission 5
#
# Rename the columns [of this dataset](https://raw.githubusercontent.com/justmarkham/pandas-videos/master/data/ufo.csv), try using the following 2 different methods to achieve this:
# - Setting column names directly when reading the file
# - Editing after creating the dataframe ([This resource could be useful](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.rename.html))

# %%
names_column=["Ville","Couleur","Forme","Status","Heure"]
df=pd.read_csv("https://raw.githubusercontent.com/justmarkham/pandas-videos/master/data/ufo.csv", names=names_column, header=None,  skiprows=1,encoding='ISO-8859-1')
df.head(5)
# Out:
#                   Ville Couleur     Forme Status            Heure
# 0                Ithaca     NaN  TRIANGLE     NY   6/1/1930 22:00
# 1           Willingboro     NaN     OTHER     NJ  6/30/1930 20:00
# 2               Holyoke     NaN      OVAL     CO  2/15/1931 14:00
# 3               Abilene     NaN      DISK     KS   6/1/1931 13:00
# 4  New York Worlds Fair     NaN     LIGHT     NY  4/18/1933 19:00

# %%
# Autre Methode
# names_column=["Ville","Couleur","Forme","Status","Heure"]

# récupération des noms de colonnes
names_column=df.columns.tolist()
print(names_column)
# Création de la nouvelle liste de colonnes
names_column2=["Ville2","Couleur2","Forme2","Status2","Heure2"]
# Mapping entre les 2 listes
mapping_names=dict(zip(names_column, names_column2))

# renommage des colonnes
df.rename(columns=mapping_names, inplace=True)
df.head(5)
# Out:
# ['Ville', 'Couleur', 'Forme', 'Status', 'Heure']
#                  Ville2 Couleur2    Forme2 Status2           Heure2
# 0                Ithaca      NaN  TRIANGLE      NY   6/1/1930 22:00
# 1           Willingboro      NaN     OTHER      NJ  6/30/1930 20:00
# 2               Holyoke      NaN      OVAL      CO  2/15/1931 14:00
# 3               Abilene      NaN      DISK      KS   6/1/1931 13:00
# 4  New York Worlds Fair      NaN     LIGHT      NY  4/18/1933 19:00

# %% [markdown]
# # Mission 6
#
# Select the first 3 rows and all the columns of the dataframe using iloc

# %%
df.iloc[:3,:]
# Out:
#         Ville2 Couleur2    Forme2 Status2           Heure2
# 0       Ithaca      NaN  TRIANGLE      NY   6/1/1930 22:00
# 1  Willingboro      NaN     OTHER      NJ  6/30/1930 20:00
# 2      Holyoke      NaN      OVAL      CO  2/15/1931 14:00

# %% [markdown]
# # Mission 7
#
# Achieve the same result as in mission 6 by using loc

# %%
df.loc[df.index[:3],:]
# Out:
#         Ville2 Couleur2    Forme2 Status2           Heure2
# 0       Ithaca      NaN  TRIANGLE      NY   6/1/1930 22:00
# 1  Willingboro      NaN     OTHER      NJ  6/30/1930 20:00
# 2      Holyoke      NaN      OVAL      CO  2/15/1931 14:00

# %%
# Pour avoir uniquement la 3 éme ligne
df.iloc[2,:]
# Out:
# Ville2              Holyoke
# Couleur2                NaN
# Forme2                 OVAL
# Status2                  CO
# Heure2      2/15/1931 14:00
# Name: 2, dtype: object

# %%
#  autre solution avec loc
df.loc[df.index[2],:]  # le ',:' est optionnel dans ce cas
# Out:
# Ville2              Holyoke
# Couleur2                NaN
# Forme2                 OVAL
# Status2                  CO
# Heure2      2/15/1931 14:00
# Name: 2, dtype: object
