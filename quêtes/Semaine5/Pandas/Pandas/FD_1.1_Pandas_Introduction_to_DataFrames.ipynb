# %%
import pandas as pd
import numpy as np

# %% [markdown]
# # Méthode infos sur le dataframe

# %%
df_fruit_vendors.shape

# %%
df_fruit_vendors.info()

# %%
df_fruit_vendors.describe()

# %%
df_fruit_vendors.size

# %% [markdown]
# # Mission 1
#
# ![](https://i.imgur.com/Ax3pp2A.png)
#
#
# Create a "fruit" dataframe that reflects the above example **using a list** data structure
#
# [This resource could help you](https://datatofish.com/list-to-dataframe/).

# %%
my_dico=[{"Apples":30,"Bananas":21}]
fruit= pd.DataFrame(my_dico)
# df = pd.DataFrame(data=d, dtype=np.int8)  #juste car c'est meilleur pour la planéte
fruit
# del fruit
# Out:
#    Apples  Bananas
# 0      30       21

# %% [markdown]
# # Mission 2
#
# Create a "fruit_vendors" dataframe that reflects the below example **using a dictionary** data structure
#
# ![](https://i.imgur.com/CHPn7ZF.png)
#
# [This resource could help you.](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.from_dict.html)

# %%
my_vendors={
    "Apples":{
        "2017 Sales":35,
        "2018 Sales":41
        },
    "Bananas":{
        "2017 Sales":21,
        "2018 Sales":34
               }
    }
fruit_vendors= pd.DataFrame(my_vendors)

# df = pd.DataFrame(data=d, dtype=np.int8)  #juste car c'est meilleur pour la planéte
fruit_vendors
# Out:
#             Apples  Bananas
# 2017 Sales      35       21
# 2018 Sales      41       34

# %%
# Autre SOlution
my_vendors=[
    [35,21],
    [41,34]
    ]
data=my_vendors
index=["2017 Sales","2018 Sales"]
columns=["Apples","Bananas"]
df_fruit_vendors= pd.DataFrame(data, index, columns, dtype=np.int8)
# dtype=np.int8  #juste car c'est meilleur pour la planéte
df_fruit_vendors
# Out:
#             Apples  Bananas
# 2017 Sales      35       21
# 2018 Sales      41       34

# %% [markdown]
# # Mission 3
#
# Use a loop to display the values from each column in the dataframe from mission 2.

# %%
for column in df_fruit_vendors.columns:
    print(f"valeur colonne {column} :{df_fruit_vendors[column].values}")
# Out:
# valeur colonne Apples :[35 41]
# valeur colonne Bananas :[21 34]

# %% [markdown]
# # Mission 3 fd
#
# Use a loop to display the values from each rows in the dataframe from mission 2.

# %%
for index,row in df_fruit_vendors.iterrows():
   print(f"valeur ligne :{index} = {row.values}")
# Out:
# valeur ligne :2017 Sales =[35 21]
# valeur ligne :2018 Sales =[41 34]

# %% [markdown]
# # Mission 4
#
# Delete the first row of the dataframe from mission 2
#
# [This resource could help you.](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.drop.html)

# %%
df_fruit_vendors2=df_fruit_vendors.copy()
df_fruit_vendors2.drop(index[0], axis=0, inplace=True)
print(df_fruit_vendors2)
# Out:
#             Apples  Bananas
# 2018 Sales      41       34

# %% [markdown]
# # Mission 5
#
# Delete the first column from the dataframe from mission 2.

# %%
df_fruit_vendors2.drop(["Apples"], axis=1, inplace=True)
print(df_fruit_vendors2)
# Out:
#             Bananas
# 2018 Sales       34
