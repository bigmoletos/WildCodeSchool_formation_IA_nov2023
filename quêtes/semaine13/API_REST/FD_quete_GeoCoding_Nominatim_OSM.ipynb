# %% [markdown]
# # Introduction
# ## Cartographie avec folium de geopy
# The Nominatim API is a REST API (provided by OpenStreetMap), that returns geographic coordinates (latitude and longitude) from a postal address. If several postal addresses (due to inaccuracy or non-existent street number) corresponding to the request are found, the API returns several coordinates, each time with an `importance` score. The coordinates are given in descending order of importance, so you can select only the first address.

# %%
# Execute the code below :

import requests
link = "https://nominatim.openstreetmap.org/?q=54+Via+Pietro+Mascagni,Catania,Italy&format=json"
r = requests.get(link).json()
r
# Out:
# [{'place_id': 45768607,
#   'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright',
#   'osm_type': 'way',
#   'osm_id': 1203329854,
#   'lat': '37.7242361',
#   'lon': '15.1789984',
#   'class': 'highway',
#   'type': 'residential',
#   'place_rank': 26,
#   'importance': 0.10000999999999993,
#   'addresstype': 'road',
#   'name': 'Via Pietro Mascagni',
#   'display_name': 'Via Pietro Mascagni, Altarello, Giarre, Catania, Sicilia, 95014, Italia',
#   'boundingbox': ['37.7234970', '37.7249937', '15.1784912', '15.1794786']},
#  {'place_id': 45825211,
#   'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright',
#   'osm_type': 'way',
#   'osm_id': 58232256,
#   'lat': '37.6091358',
#   'lon': '15.1596388',
#   'class': 'highway',
#   'type': 'residential',
#   'place_rank': 26,
#   'importance': 0.10000999999999993,
#   'addresstype': 'road',
#   'name': 'Via Pietro Mascagni',
#   'display_name': 'Via Pietro Mascagni, Sciarelle, Acireale, Catania, Sicilia, 95024, Italia',
#   'boundingbox': ['37.6088571', '37.6091358', '15.1591549', '15.1602847']},
#  {'place_id': 46092251,
#   'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright',
#   'osm_type': 'way',
#   'osm_id': 167016177,
#   'lat': '37.5676811',
#   'lon': '14.9106709',
#   'class': 'highway',
#   'type': 'residential',
#   'place_rank': 26,
#   'importance': 0.10000999999999993,
#   'addresstype': 'road',
#   'name': 'Via Pietro Mascagni',
#   'display_name': 'Via Pietro Mascagni, Paternò, Catania, Sicilia, 95047, Italia',
#   'boundingbox': ['37.5673863', '37.5680619', '14.9106500', '14.9109837']},
#  {'place_id': 46246631,
#   'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright',
#   'osm_type': 'way',
#   'osm_id': 540088607,
#   'lat': '37.7871742',
#   'lon': '14.8355931',
#   'class': 'highway',
#   'type': 'residential',
#   'place_rank': 26,
#   'importance': 0.10000999999999993,
#   'addresstype': 'road',
#   'name': 'Via Pietro Mascagni',
#   'display_name': 'Via Pietro Mascagni, Bronte, Catania, Sicilia, 95034, Italia',
#   'boundingbox': ['37.7871116', '37.7872091', '14.8351854', '14.8361387']},
#  {'place_id': 46279928,
#   'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright',
#   'osm_type': 'way',
#   'osm_id': 79698554,
#   'lat': '37.5113199',
#   'lon': '14.9671802',
#   'class': 'highway',
#   'type': 'residential',
#   'place_rank': 26,
#   'importance': 0.10000999999999993,
#   'addresstype': 'road',
#   'name': 'Via Pietro Mascagni',
#   'display_name': "Via Pietro Mascagni, Motta Sant'Anastasia, Catania, Sicilia, 95040, Italia",
#   'boundingbox': ['37.5112501', '37.5113840', '14.9664393', '14.9678432']},
#  {'place_id': 45255854,
#   'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright',
#   'osm_type': 'way',
#   'osm_id': 189209554,
#   'lat': '37.6231375',
#   'lon': '15.0518243',
#   'class': 'highway',
#   'type': 'residential',
#   'place_rank': 26,
#   'importance': 0.10000999999999993,
#   'addresstype': 'road',
#   'name': 'Via Pietro Mascagni',
#   'display_name': 'Via Pietro Mascagni, Pedara, Catania, Sicilia, 95030, Italia',
#   'boundingbox': ['37.6228284', '37.6245581', '15.0510077', '15.0528415']},
#  {'place_id': 45320180,
#   'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright',
#   'osm_type': 'way',
#   'osm_id': 206283540,
#   'lat': '37.6241385',
#   'lon': '15.0145038',
#   'class': 'highway',
#   'type': 'residential',
#   'place_rank': 26,
#   'importance': 0.10000999999999993,
#   'addresstype': 'road',
#   'name': 'Via Pietro Mascagni',
#   'display_name': 'Via Pietro Mascagni, Nicolosi, Catania, Sicilia, 95030, Italia',
#   'boundingbox': ['37.6230119', '37.6248887', '15.0142476', '15.0152742']},
#  {'place_id': 45387122,
#   'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright',
#   'osm_type': 'way',
#   'osm_id': 230562894,
#   'lat': '37.6167523',
#   'lon': '15.0750989',
#   'class': 'highway',
#   'type': 'residential',
#   'place_rank': 26,
#   'importance': 0.10000999999999993,
#   'addresstype': 'road',
#   'name': 'Via Pietro Mascagni',
#   'display_name': 'Via Pietro Mascagni, Tondo, Trecastagni, Catania, Sicilia, 95039, Italia',
#   'boundingbox': ['37.6161948', '37.6171473', '15.0750886', '15.0751069']},
#  {'place_id': 45669124,
#   'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright',
#   'osm_type': 'way',
#   'osm_id': 483323874,
#   'lat': '37.5971037',
#   'lon': '15.1011869',
#   'class': 'highway',
#   'type': 'residential',
#   'place_rank': 26,
#   'importance': 0.10000999999999993,
#   'addresstype': 'road',
#   'name': 'Via Pietro Mascagni / Via Bottazzi',
#   'display_name': 'Via Pietro Mascagni / Via Bottazzi, Aci Bonaccorsi, Catania, Sicilia, 95020, Italia',
#   'boundingbox': ['37.5967751', '37.5975168', '15.1008153', '15.1015795']},
#  {'place_id': 45702684,
#   'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright',
#   'osm_type': 'way',
#   'osm_id': 132278438,
#   'lat': '37.608989',
#   'lon': '15.1226199',
#   'class': 'highway',
#   'type': 'residential',
#   'place_rank': 26,
#   'importance': 0.10000999999999993,
#   'addresstype': 'road',
#   'name': 'Via Pietro Mascagni',
#   'display_name': "Via Pietro Mascagni, Aci Sant'Antonio, Catania, Sicilia, 95025, Italia",
#   'boundingbox': ['37.6082673', '37.6094120', '15.1224766', '15.1228643']}]

# %%
# Here we select only the first address (index 0)
print("First address :", r[0])
print("First address longitude :",r[0]['lon'])
print("First address latitude :",r[0]['lat'])
# Out:
# First address : {'place_id': 45768607, 'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright', 'osm_type': 'way', 'osm_id': 1203329854, 'lat': '37.7242361', 'lon': '15.1789984', 'class': 'highway', 'type': 'residential', 'place_rank': 26, 'importance': 0.10000999999999993, 'addresstype': 'road', 'name': 'Via Pietro Mascagni', 'display_name': 'Via Pietro Mascagni, Altarello, Giarre, Catania, Sicilia, 95014, Italia', 'boundingbox': ['37.7234970', '37.7249937', '15.1784912', '15.1794786']}
# First address longitude : 15.1789984
# First address latitude : 37.7242361

# %%
# For ease of use, you can add a limit on the number of items returned:

link = "https://nominatim.openstreetmap.org/?q=54+Via+Pietro+Mascagni,Catania,Italy&format=json"
r = requests.get(link).json()
print("WITHOUT limit, how many coordinates does this address return?",len(r))

link = "https://nominatim.openstreetmap.org/?q=54+Via+Pietro+Mascagni,Catania,Italy&format=json&limit=1"
r = requests.get(link).json()
print("WITH limit, how many coordinates does this address return?",len(r))
# Out:
# WITHOUT limit, how many coordinates does this address return? 10
# WITH limit, how many coordinates does this address return? 1

# %% [markdown]
# ## How to create your API query
# It's up to you to modify the string to create the right request URL

# %%
# We observe that the query consists of a fixed part, followed by the address to be searched for.
# An URL cannot contain a " " space character,
# and special characters or accents should be avoided if possible
import urllib.parse
link_main = 'https://nominatim.openstreetmap.org/?q='
adresse = '54 Via Pietro Mascagni, Catania, Italy'
link_end = '&format=json&limit=1'

link = link_main +  urllib.parse.quote_plus(adresse)

print(link + link_end)
# Out:
# https://nominatim.openstreetmap.org/?q=54+Via+Pietro+Mascagni%2C+Catania%2C+Italy&format=json&limit=1

# %%
import requests
import urllib.parse

def get_coordinates(adresse):
    link_main = 'https://api-adresse.data.gouv.fr/search/?q='

    # Remplacer les espaces par des '+'
    adresse = urllib.parse.quote_plus(adresse)

    # Construire l'URL
    url = f"{link_main}{adresse}"

    # Effectuer la requête
    response = requests.get(url)

    # Vérifier que la requête a réussi
    if response.status_code == 200:
        data = response.json()

        # Extraire les coordonnées
        if 'features' in data:
            coordinates = data['features'][0]['geometry']['coordinates'][::-1] # on inverse latitude et longitude
            return coordinates
        else:
            return None
    else:
        print(f"Erreur lors de la requête : {response.status_code}")
        return None

# %%
# Create a function here that turns a postal address into a request URL for the Nominatim API,
# then makes the request and returns the coordinates :

import requests
import urllib.parse

def api_address_geopy(adresse):
    link_main = 'https://nominatim.openstreetmap.org/?q='
    link_end = '&format=json&limit=1'

    # Remplacer les espaces par des '+'
    adresse = urllib.parse.quote_plus(adresse)

    # Construire l'URL
    url = f"{link_main}{adresse}{link_end}"
    print(f"\nurl :\n{url} \n")
    # Effectuer la requête
    response = requests.get(url)

    # Vérifier que la requête a réussi
    if response.status_code == 200:
        data = response.json()

        # Extraire les coordonnées
        if 'features' in data:

            coordinates = data['features'][0]['geometry']['coordinates'][::-1] # on inverse latitude et longitude
            print(f"\ncoordinates :\n{coordinates} \n")
            return coordinates
        else:
            return None
    else:
        print(f"Erreur lors de la requête : {response.status_code}")
        return None

# %%
# Test it here:
coordinate=API_address(adresse)
coordinate
# Out:
# [42.575417, 9.002372]

# %% [markdown]
# # DataViz
# Latitude & Longitude can be used on visualization tools, whether they are BI tools (PowerBI, Table), or Python DataViz libraries such as Plotly or Folium.
#
# Here we will display a map with Folium.

# %%
# The syntax of Folium is very simple, you start by creating a map centered on a point.
# You can change the default zoom level with the argument "zoom_start".

import folium

# We define a location as a list with 2 values : latitude and longitude.
point = [float(r[0]['lat']), float(r[0]['lon'])]

# We center the map on the location
m = folium.Map(location=point,zoom_start=7)

# We display the map
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_4d6438bb7d2e41ccac85326d8155f911 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_4d6438bb7d2e41ccac85326d8155f911&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_4d6438bb7d2e41ccac85326d8155f911 = L.map(
#                 &quot;map_4d6438bb7d2e41ccac85326d8155f911&quot;,
#                 {
#                     center: [37.7242361, 15.1789984],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 7,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_262524848b9194befcc1711ba2abada2 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_262524848b9194befcc1711ba2abada2.addTo(map_4d6438bb7d2e41ccac85326d8155f911);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
# Then you can add landmarks and put a clickable comment
m = folium.Map(location=point, )
folium.Marker(
    location=point,
    popup='a good restaurant'
    ).add_to(m)
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_6802d6b41c91d6f8c9ace54ce77381ce {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_6802d6b41c91d6f8c9ace54ce77381ce&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_6802d6b41c91d6f8c9ace54ce77381ce = L.map(
#                 &quot;map_6802d6b41c91d6f8c9ace54ce77381ce&quot;,
#                 {
#                     center: [37.7242361, 15.1789984],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_521c91415515b1eaa3d911836aa93f1a = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_521c91415515b1eaa3d911836aa93f1a.addTo(map_6802d6b41c91d6f8c9ace54ce77381ce);
#
#
#             var marker_07a247f42d2041ae3b61289dc27d2aa1 = L.marker(
#                 [37.7242361, 15.1789984],
#                 {}
#             ).addTo(map_6802d6b41c91d6f8c9ace54ce77381ce);
#
#
#         var popup_474b9d8c01ba9cdd54bf75ef4c6dff1c = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_866ec45bd110db27bca7dfa3debe9702 = $(`&lt;div id=&quot;html_866ec45bd110db27bca7dfa3debe9702&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;a good restaurant&lt;/div&gt;`)[0];
#                 popup_474b9d8c01ba9cdd54bf75ef4c6dff1c.setContent(html_866ec45bd110db27bca7dfa3debe9702);
#
#
#
#         marker_07a247f42d2041ae3b61289dc27d2aa1.bindPopup(popup_474b9d8c01ba9cdd54bf75ef4c6dff1c)
#         ;
#
#
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# # Challenge
# Here is a DataFrame with restaurants in Catania, Sicily, and their respective addresses. Here is your mission:
# - Create a new column "coordinates", which will store the coordinates corresponding to each address (you can use the function you created previously).
# - Display a map with the 4 restaurant markers. Be careful, the restaurants are very close, remember to set the default zoom level so that it is clearly legible. You can center the map on the first restaurant. And display the name of the restaurant in the tooltip popup.

# %%
import pandas as pd
restaurants = pd.DataFrame([["Gelateria Zio Pietro dal 1964", "Via Porta di Ferro, 47, 95131 Catania CT"],
                            ["A Casa d'Amici","Via Fischetti, 14, 95131 Catania CT"],
                            ["La Bitta", "Via Acquicella Porto, 95121 Catania CT"],
                            ["Steak House", "Via Porta di Ferro, 8, 95100 Catania CT"]
                            ],
                           columns = ["name", "address"])

restaurants
# Out:
#                             name                                   address
# 0  Gelateria Zio Pietro dal 1964  Via Porta di Ferro, 47, 95131 Catania CT
# 1                 A Casa d'Amici       Via Fischetti, 14, 95131 Catania CT
# 2                       La Bitta    Via Acquicella Porto, 95121 Catania CT
# 3                    Steak House   Via Porta di Ferro, 8, 95100 Catania CT

# %%
# !pip install geopy
# Out:
# Collecting geopy
#   Using cached geopy-2.4.1-py3-none-any.whl.metadata (6.8 kB)
# Collecting geographiclib<3,>=1.52 (from geopy)
#   Using cached geographiclib-2.0-py3-none-any.whl (40 kB)
# Using cached geopy-2.4.1-py3-none-any.whl (125 kB)
# Installing collected packages: geographiclib, geopy
# Successfully installed geographiclib-2.0 geopy-2.4.1

# %%
# import pandas as pd
# import requests
# from geopy.geocoders import Nominatim
# import folium
# # Initialize Nominatim API
# geolocator = Nominatim(user_agent="geoapiExercises")

# # Function to get coordinates
# def get_coordinates(address):
#     try:
#         location = geolocator.geocode(address)
#         return (location.lat, location.lon)
#     except:
#         return (None, None)
# Out:
#                             name                                   address  \
# 0  Gelateria Zio Pietro dal 1964  Via Porta di Ferro, 47, 95131 Catania CT
# 1                 A Casa d'Amici       Via Fischetti, 14, 95131 Catania CT
# 2                       La Bitta    Via Acquicella Porto, 95121 Catania CT
# 3                    Steak House   Via Porta di Ferro, 8, 95100 Catania CT
#
#     coordinates
# 0  (None, None)
# 1  (None, None)
# 2  (None, None)
# 3  (None, None)

# %%
import pandas as pd
import requests
from geopy.geocoders import Nominatim
import folium

def api_address_geopy(adresse):
    link_main = 'https://nominatim.openstreetmap.org/?q='
    link_end = '&format=json&limit=1'

    # Remplacer les espaces par des '+'
    adresse = urllib.parse.quote_plus(adresse)

    # Construire l'URL
    url = f"{link_main}{adresse}{link_end}"
    # print(f"\nurl :\n{url} \n")
    # Effectuer la requête
    response = requests.get(url)

    # Vérifier que la requête a réussi
    if response.status_code == 200:
        data = response.json()
        # print(f"\n data:\n{data} \n")
        # Extraire les coordonnées
        if  data:
            coordinates = [float(data[0]['lat']), float(data[0]['lon'])]
            # coordinates = data['features'][0]['geometry']['coordinates'][::-1] # on inverse latitude et longitude
            # print(f"\ncoordinates :\n{coordinates} \n")
            return coordinates
        else:
            return None
    else:
        print(f"Erreur lors de la requête : {response.status_code}")
        return None

# %%
# Creation de la colonne  'coordinates'
# restaurants['coordinates'] = restaurants['address'].apply(get_coordinates)
# restaurants['coordinates'] = restaurants['address'].apply(api_address_geopy)
restaurants['coordinates'] = restaurants['address'].apply(api_address_geopy)
restaurants
# Out:
#                             name                                   address  \
# 0  Gelateria Zio Pietro dal 1964  Via Porta di Ferro, 47, 95131 Catania CT
# 1                 A Casa d'Amici       Via Fischetti, 14, 95131 Catania CT
# 2                       La Bitta    Via Acquicella Porto, 95121 Catania CT
# 3                    Steak House   Via Porta di Ferro, 8, 95100 Catania CT
#
#                 coordinates
# 0  [37.5020931, 15.0931951]
# 1   [37.506171, 15.0943223]
# 2  [37.4894646, 15.0792388]
# 3  [37.5029335, 15.0930406]

# %%
#  test des 3  fonctions
# coord\ncoordininate=get_coordinates(restaurants['address'][0])
# print(f"\ncoordinate :\n{coordinate} \n")

# coordinate=API_address(restaurants['address'][0])
# print(f"ate :\n{coordinate} \n")

coordinate=api_address_geopy(restaurants['address'][0])
print(f"\ncoordinate :\n{coordinate} \n")
# Out:
# coordinate :
# [37.5020931, 15.0931951]

# %%
import folium

# Assuming 'restaurants' DataFrame already has a 'coordinates' column with the correct data

# Create a Folium map with a default view that will be adjusted later
m = folium.Map( width='80%', height='50%')

# Add markers for each restaurant and collect the coordinates in a list to adjust the map view bounds later
coordinates_list = []
for idx, row in restaurants.iterrows():
    folium.Marker(
        location=row['coordinates'],
        popup=row['name'],
        tooltip=row['name']
    ).add_to(m)
    coordinates_list.append(row['coordinates'])

# Use fit_bounds to automatically adjust the zoom and the centering of the map to include all points
# We add a little padding using the 'padding' parameter to ensure all markers are visible
if coordinates_list:
    m.fit_bounds(coordinates_list, padding=(50, 50))  # You can adjust the padding as needed

# Show the map
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_d49dc26d04c679b6ca28b166279e896e {
#                     position: relative;
#                     width: 80.0%;
#                     height: 50.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_d49dc26d04c679b6ca28b166279e896e&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_d49dc26d04c679b6ca28b166279e896e = L.map(
#                 &quot;map_d49dc26d04c679b6ca28b166279e896e&quot;,
#                 {
#                     center: [0.0, 0.0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 1,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_8f37e6b82587eb92e0933a0f1053468c = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_8f37e6b82587eb92e0933a0f1053468c.addTo(map_d49dc26d04c679b6ca28b166279e896e);
#
#
#             var marker_d5e411aabd601d2e70a2d659727f5abd = L.marker(
#                 [37.5020931, 15.0931951],
#                 {}
#             ).addTo(map_d49dc26d04c679b6ca28b166279e896e);
#
#
#         var popup_18f6f8e27f6cbbbd50061dfac5c7c8a1 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_95fa6db369a3bb2db614ca274221b18b = $(`&lt;div id=&quot;html_95fa6db369a3bb2db614ca274221b18b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Gelateria Zio Pietro dal 1964&lt;/div&gt;`)[0];
#                 popup_18f6f8e27f6cbbbd50061dfac5c7c8a1.setContent(html_95fa6db369a3bb2db614ca274221b18b);
#
#
#
#         marker_d5e411aabd601d2e70a2d659727f5abd.bindPopup(popup_18f6f8e27f6cbbbd50061dfac5c7c8a1)
#         ;
#
#
#
#
#             marker_d5e411aabd601d2e70a2d659727f5abd.bindTooltip(
#                 `&lt;div&gt;
#                      Gelateria Zio Pietro dal 1964
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_e589a5e97060f718fcda2c7783ec3a7d = L.marker(
#                 [37.506171, 15.0943223],
#                 {}
#             ).addTo(map_d49dc26d04c679b6ca28b166279e896e);
#
#
#         var popup_b67477902a5e7b48946b972f3eb7f6e0 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_aba2e091f7ef784ba70793e49a54e857 = $(`&lt;div id=&quot;html_aba2e091f7ef784ba70793e49a54e857&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;A Casa d&#x27;Amici&lt;/div&gt;`)[0];
#                 popup_b67477902a5e7b48946b972f3eb7f6e0.setContent(html_aba2e091f7ef784ba70793e49a54e857);
#
#
#
#         marker_e589a5e97060f718fcda2c7783ec3a7d.bindPopup(popup_b67477902a5e7b48946b972f3eb7f6e0)
#         ;
#
#
#
#
#             marker_e589a5e97060f718fcda2c7783ec3a7d.bindTooltip(
#                 `&lt;div&gt;
#                      A Casa d&#x27;Amici
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_d912bb41d7338acf0f58922845e8b903 = L.marker(
#                 [37.4894646, 15.0792388],
#                 {}
#             ).addTo(map_d49dc26d04c679b6ca28b166279e896e);
#
#
#         var popup_3d0215ce0cd5678ac0548c77e61cac79 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_bd7146f660a7a3a279a1dc191ac79250 = $(`&lt;div id=&quot;html_bd7146f660a7a3a279a1dc191ac79250&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;La Bitta&lt;/div&gt;`)[0];
#                 popup_3d0215ce0cd5678ac0548c77e61cac79.setContent(html_bd7146f660a7a3a279a1dc191ac79250);
#
#
#
#         marker_d912bb41d7338acf0f58922845e8b903.bindPopup(popup_3d0215ce0cd5678ac0548c77e61cac79)
#         ;
#
#
#
#
#             marker_d912bb41d7338acf0f58922845e8b903.bindTooltip(
#                 `&lt;div&gt;
#                      La Bitta
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_14bd91e117c846fd344ae42eb257ab7e = L.marker(
#                 [37.5029335, 15.0930406],
#                 {}
#             ).addTo(map_d49dc26d04c679b6ca28b166279e896e);
#
#
#         var popup_ee3b5997b571f15d77e0118e6b556468 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_d70f41112c23e9cd4e52ab3f0b6926e5 = $(`&lt;div id=&quot;html_d70f41112c23e9cd4e52ab3f0b6926e5&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Steak House&lt;/div&gt;`)[0];
#                 popup_ee3b5997b571f15d77e0118e6b556468.setContent(html_d70f41112c23e9cd4e52ab3f0b6926e5);
#
#
#
#         marker_14bd91e117c846fd344ae42eb257ab7e.bindPopup(popup_ee3b5997b571f15d77e0118e6b556468)
#         ;
#
#
#
#
#             marker_14bd91e117c846fd344ae42eb257ab7e.bindTooltip(
#                 `&lt;div&gt;
#                      Steak House
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             map_d49dc26d04c679

# %%
from geopy.geocoders import Nominatim
import folium

# # Generate map
# m = folium.Map(location=restaurants['coordinates'][0], zoom_start=12)

# Calculate the average coordinates to center the map
average_coords = [restaurants['coordinates'].str[0].mean(), restaurants['coordinates'].str[1].mean()]
# Create a Folium map centered around the average coordinates
m = folium.Map(location=average_coords, zoom_start=14, width='50%', height='50%')

# # Calculate the center of all markers
# latitudes = [coord[0] for coord in restaurants['coordinates']]
# longitudes = [coord[1] for coord in restaurants['coordinates']]
# center = [sum(latitudes) / len(latitudes), sum(longitudes) / len(longitudes)]
# # Generate map
# m = folium.Map(location=center, zoom_start=12)


# Add markers to the map
for idx, row in restaurants.iterrows():
    folium.Marker(
        location=row['coordinates'],
        popup=row['name'],
        tooltip=row['name']
    ).add_to(m)

# Show the map
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_1518c287554e911b0c918fdbe970741d {
#                     position: relative;
#                     width: 50.0%;
#                     height: 50.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_1518c287554e911b0c918fdbe970741d&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_1518c287554e911b0c918fdbe970741d = L.map(
#                 &quot;map_1518c287554e911b0c918fdbe970741d&quot;,
#                 {
#                     center: [37.500165550000006, 15.089949200000001],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 14,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_ff4f34e4223f8311b2159c4b99f1544a = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_ff4f34e4223f8311b2159c4b99f1544a.addTo(map_1518c287554e911b0c918fdbe970741d);
#
#
#             var marker_dd9b17fad2eff83fee2c3150e85dff7d = L.marker(
#                 [37.5020931, 15.0931951],
#                 {}
#             ).addTo(map_1518c287554e911b0c918fdbe970741d);
#
#
#         var popup_1b14f3abf0886f5eea3a0aa96a3e52c2 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_25a40e4a11ec691f88866dcc84054789 = $(`&lt;div id=&quot;html_25a40e4a11ec691f88866dcc84054789&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Gelateria Zio Pietro dal 1964&lt;/div&gt;`)[0];
#                 popup_1b14f3abf0886f5eea3a0aa96a3e52c2.setContent(html_25a40e4a11ec691f88866dcc84054789);
#
#
#
#         marker_dd9b17fad2eff83fee2c3150e85dff7d.bindPopup(popup_1b14f3abf0886f5eea3a0aa96a3e52c2)
#         ;
#
#
#
#
#             marker_dd9b17fad2eff83fee2c3150e85dff7d.bindTooltip(
#                 `&lt;div&gt;
#                      Gelateria Zio Pietro dal 1964
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_b2139efa612643d3ef70a8e697eba5d6 = L.marker(
#                 [37.506171, 15.0943223],
#                 {}
#             ).addTo(map_1518c287554e911b0c918fdbe970741d);
#
#
#         var popup_2c487528b5f48eacbf9177070732cc8f = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_1675095f0759f0ab8de180594d42c645 = $(`&lt;div id=&quot;html_1675095f0759f0ab8de180594d42c645&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;A Casa d&#x27;Amici&lt;/div&gt;`)[0];
#                 popup_2c487528b5f48eacbf9177070732cc8f.setContent(html_1675095f0759f0ab8de180594d42c645);
#
#
#
#         marker_b2139efa612643d3ef70a8e697eba5d6.bindPopup(popup_2c487528b5f48eacbf9177070732cc8f)
#         ;
#
#
#
#
#             marker_b2139efa612643d3ef70a8e697eba5d6.bindTooltip(
#                 `&lt;div&gt;
#                      A Casa d&#x27;Amici
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_8cbd5401ec902d9ec8b040ea0e837818 = L.marker(
#                 [37.4894646, 15.0792388],
#                 {}
#             ).addTo(map_1518c287554e911b0c918fdbe970741d);
#
#
#         var popup_64ef814dea82d2803c5efbdf347ceae6 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_397cbdf000cd8619e07925c3a6019ca3 = $(`&lt;div id=&quot;html_397cbdf000cd8619e07925c3a6019ca3&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;La Bitta&lt;/div&gt;`)[0];
#                 popup_64ef814dea82d2803c5efbdf347ceae6.setContent(html_397cbdf000cd8619e07925c3a6019ca3);
#
#
#
#         marker_8cbd5401ec902d9ec8b040ea0e837818.bindPopup(popup_64ef814dea82d2803c5efbdf347ceae6)
#         ;
#
#
#
#
#             marker_8cbd5401ec902d9ec8b040ea0e837818.bindTooltip(
#                 `&lt;div&gt;
#                      La Bitta
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_3b504e22ac5303682e2fc3456f0f9747 = L.marker(
#                 [37.5029335, 15.0930406],
#                 {}
#             ).addTo(map_1518c287554e911b0c918fdbe970741d);
#
#
#         var popup_18bb7a2b74094110c88723de05986633 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_a9c5a60450863630f94cbf8a7d1d0f87 = $(`&lt;div id=&quot;html_a9c5a60450863630f94cbf8a7d1d0f87&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Steak House&lt;/div&gt;`)[0];
#                 popup_18bb7a2b74094110c88723de05986633.setContent(html_a9c5a60450863630f94cbf8a7d1d0f87);
#
#
#
#         marker_3b504e22ac5303682e2fc3456f0f9747.bindPopup(popup_18bb7a2b74094110c88723de05986633)
#         ;
#
#
#
#
#             marker_3b504e22ac5303682e2fc3456f0f9747.bindTooltip(
#                 `&lt;div&gt;
#                      Steak House
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
# &lt;

# %% [markdown]
# # Remarks on the Nominatim API
# As indicated in the quest, there are many resources for geocoding. Most of them are available by registration, and some require a fee.
#
# The Nominatim API is free and without registration. The disadvantage is that it is relatively slow. If you need to use it in the future, remember to store the results so you don't have to run it several times.
#
# For your knowledge, there is also :
# - the **reverse** address API, which allows you to find the nearest postal address using geographic coordinates.
# - the API from a **CSV file** if you have a lot of addresses to geocode
# - the API **GeoJSON** which allows to obtain a geoJSON format of locations to make choropleth maps
#
#
# All the [documentation is available here](https://nominatim.org/release-docs/develop/api/Search/).
