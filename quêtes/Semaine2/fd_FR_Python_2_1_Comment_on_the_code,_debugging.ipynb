# %% [markdown]
# # Mission 1: Commenter son code

# %% [markdown]
# Une clé pour progresser rapidement en Python:
# Commenter le code.
# On ne te le répètera jamais assez, commente ton code.
# Cette bonne pratique va te rassurer, car tu comprends ainsi ce qu'il se passe à chaque ligne de code, sans louper d'étapes.
#
# "*Rien ne sert de courir, il faut partir à point.*"

# %% [markdown]
# ![comment.png](data:image/png;base64,...)

# %% [markdown]
# C'est à ton tour de commenter le code ci-dessous.
# Pour t'entraîner, n'hésite pas à faire le calcul de tête, pour savoir combien de fois apparaîtront chaque mot.

# %%
"""
Quete Python semaine 2
FR Python 2.1 Comment on the code, debugging
"""
# initialisation du tableau vide 'une_macedoine'
une_macedoine = []
# boucle permetttant de remplir notre liste. De 4 à 120 exlcus en comptant par pas de 3
for nectarifaire in range(4,120,3):
#    on ne prend que les valeurs supérieures à 40
  if nectarifaire > 40:
    # Si le nom bre est superieur à 40, ajout des valeurs carotte et flageolet dans notre liste
    une_macedoine.append("carotte")
    une_macedoine.append("flageolet")

# %% [markdown]
# # Mission 2 : Débugger son code

# %% [markdown]
# Tu as déjà du remarqué que quand tu débutes en Python, et que tu vois un code comme ci-dessus, ça donne des sueurs froides.
# En effet, on est rapidement perdu par rapport à ce qu'il se passe.
# Pas de panique ! C'est tout à fait normal.
# Connaître les objets et leurs différences, c'est une chose.
# Mais parvenir à comprendre ce qu'il se passe quand on code, c'en est une autre.

# %% [markdown]
# ![quête python.png](data:image/png;base64,...)

# %% [markdown]
# Comme tu peux le voir ci-dessus, plusieurs `print()`ont été placés. C'est très utile pour comprendre ce qu'il se passe dans le code.
# Si tu utilises cette bonne pratique, ta progression dans la mâitrise de Python va considérablement augmenter !

# %% [markdown]
# Ton objectif dans cette mission, c'est de savoir ce qui est contenu dans chacune des variables, après exécution du code ci-dessous.
# Pour y parvenir, tu as uniquement le droit de mettre des `print()`intermédiaires (c'est à dire entre les lignes), en 'printant"(affichant)la ou les variables de ton choix. Pour cette mission, tu n'as pas le droit d'afficher les variables à la fin de la cellule, ou dans une autre cellule.

# %%
joga_bonito = []
joga_bonito_1 = []
compteur = 0

for vvv in "Bonjour":
  print("vvv:",vvv)
  for v in vvv:
    print("v:",v)
    bonjour = "¿Hola qué tal amigos?"
    joga_bonito.append((v, bonjour))
    print("joga_bonito:",joga_bonito)
  joga_bonito_1.append(v)
  print("joga_bonito_1:",joga_bonito_1)
  compteur += len(bonjour)
  print("compteur:",compteur)
# Out:
# vvv: B
# v: B
# joga_bonito: [('B', '¿Hola qué tal amigos?')]
# joga_bonito_1: ['B']
# compteur: 21
# vvv: o
# v: o
# joga_bonito: [('B', '¿Hola qué tal amigos?'), ('o', '¿Hola qué tal amigos?')]
# joga_bonito_1: ['B', 'o']
# compteur: 42
# vvv: n
# v: n
# joga_bonito: [('B', '¿Hola qué tal amigos?'), ('o', '¿Hola qué tal amigos?'), ('n', '¿Hola qué tal amigos?')]
# joga_bonito_1: ['B', 'o', 'n']
# compteur: 63
# vvv: j
# v: j
# joga_bonito: [('B', '¿Hola qué tal amigos?'), ('o', '¿Hola qué tal amigos?'), ('n', '¿Hola qué tal amigos?'), ('j', '¿Hola qué tal amigos?')]
# joga_bonito_1: ['B', 'o', 'n', 'j']
# compteur: 84
# vvv: o
# v: o
# joga_bonito: [('B', '¿Hola qué tal amigos?'), ('o', '¿Hola qué tal amigos?'), ('n', '¿Hola qué tal amigos?'), ('j', '¿Hola qué tal amigos?'), ('o', '¿Hola qué tal amigos?')]
# joga_bonito_1: ['B', 'o', 'n', 'j', 'o']
# compteur: 105
# vvv: u
# v: u
# joga_bonito: [('B', '¿Hola qué tal amigos?'), ('o', '¿Hola qué tal amigos?'), ('n', '¿Hola qué tal amigos?'), ('j', '¿Hola qué tal amigos?'), ('o', '¿Hola qué tal amigos?'), ('u', '¿Hola qué tal amigos?')]
# joga_bonito_1: ['B', 'o', 'n', 'j', 'o', 'u']
# compteur: 126
# vvv: r
# v: r
# joga_bonito: [('B', '¿Hola qué tal amigos?'), ('o', '¿Hola qué tal amigos?'), ('n', '¿Hola qué tal amigos?'), ('j', '¿Hola qué tal amigos?'), ('o', '¿Hola qué tal amigos?'), ('u', '¿Hola qué tal amigos?'), ('r', '¿Hola qué tal amigos?')]
# joga_bonito_1: ['B', 'o', 'n', 'j', 'o', 'u', 'r']
# compteur: 147

# %% [markdown]
# # Mission 3 - Calcul

# %% [markdown]
# Pour cette mission, inspirée d'un jeu télévisé, tu vas essayer de résoudre le problème suivant:
# Tu dois combiner les variables avec des opérateurs mathématiques (*+-/)
# pour trouver le résultat 466.
# Tu assigneras le résultat à la variable `answer`.
# Attention, pour cette mission, chaque variable n'est utilisable qu'une seule fois.

# %%
# initialisation des variables
var_1 = 12
var_2 = 20
var_3 = 15
var_4 = 3
var_5 = 30
# caclul pour obtenir le résultat
answer =var_2+var_3*var_5-var_1/var_4
# init varial res
res = 466
#comparaison du résultat avec la réponse attendue
if answer == res:
  print("Tu peux passer à la mission suivante.")
# Out:
# Tu peux passer à la mission suivante.

# %% [markdown]
# # Mission 4 : Manipulation des objets et leur type

# %% [markdown]
# Pour cette mission, tu vas devoir concaténer des variables pour reproduire la phrase suivante:
#
# `"1 bouche bouche bée qu'1 bouche bouche la bouche de douche de la boucherie."`
#
# Pour y parvenir, tu peux additionner tes variables. Tu peux aussi modifier le type d'une variable, uniquement avec les  [`built-in function.`](https://docs.python.org/3/library/functions.html)

# %%
var_1 = 1
var_2 = "bouche"
var_3 = "bée"
var_4 = "la"
var_5 = "qu'"
var_6 = "de"
var_7 = "douche"
var_8 = "la"
var_9 = "boucherie."
phrase = str(var_1) + " " + var_2 + " " + var_2 + " " + var_3 + " " + var_5 + str(var_1) + " " + var_2 + " " + var_2 + " " + var_4 + " " + var_2 + " " + var_6 + " " + var_7 + " " + var_6 + " " + var_8 + " " + var_9
print(phrase)
# Out:
# 1 bouche bouche bée qu'1 bouche bouche la bouche de douche de la boucherie.

# %% [markdown]
# # Mission 5: Affectation parallèle

# %% [markdown]
# En python, certains objets peuvent contenir d'autres objets.
# C'est le cas de l'objet de type `tuple`, qui peut contenir plusieurs éléments, qui sont eux-même des objets d'un certain type.
# C'est le cas ci-dessous, avec un tuple qui contient `3 élément: 1 int et 2 strings`.
#
# Ton objectif est d'affecter chacune des valeurs contenues dans le tuple à des variables disctinctes. Tu pourras ensuite répondre aux questions qui suivent, en indiquant simplement une variable par cellule de code.

# %%
a_tuple = (3, "Wild Code School", "Rose")

# %% [markdown]
# Quel est le nom de l'école ?

# %%
nom_ecole=a_tuple[1]
print(nom_ecole)
# Out:
# Wild Code School

# %% [markdown]
# Quelle est la couleur du logo de la Wild Code School ?

# %%
couleur_logo=a_tuple[2]
print(couleur_logo)
# Out:
# Rose

# %% [markdown]
# Combien de projets tu vas réaliser pendant ta formation ?

# %%
nombre_projets=a_tuple[0]
print(nombre_projets)
# Out:
# 3

# %% [markdown]
# # Mission 6: Compteur

# %% [markdown]
# Initialise un compteur qui compte le nombre de "on" dans la phrase suivante:

# %%
phrase = "Ton tonton tond un thon à Thonon."
chaine_to_find='on'
compte_mots_found=phrase.count(chaine_to_find)
print(f"on trouve {compte_mots_found} fois la chaine de caractére '{chaine_to_find}' dans la phrase \n {phrase}")
# Out:
# on trouve 7 fois la chaine de caractére 'on' dans la phrase
#  Ton tonton tond un thon à Thonon.

# %% [markdown]
# # Mission 7: Chaining

# %% [markdown]
# Tu sais ce qu'est le "chaining" ?
# Concrètement, il s'agit d'enchaîner des méthodes les unes après les autres (en série) pour arriver à tes fins.
# Un peu comme un bon footballeur ferait pour marquer un but (passement de jambes, crochet, petit-pont, frappe et but !), tu vas devoir enchaîner les méthodes les unes après les autres pour atteindre ton objectif.
# Ton objectif, c'est d'appliquer plusieurs méthodes les unes à la suites des autres (chaining) pour obtenir la phrase suivante:
# `Ah mais vous savez, je ne pense pas qu'il y ai de bonnes ou de mauvaises situations.`
# Tu as le droit d'utiliser plusieurs fois la même méthode.

# %%
phrase = "Ah maIS vows SavUZ, je ge PUHSe Pas qw'il y Ai de BoggUS ow de MawVaiSUS siTwatIOHs."
phrase=phrase.replace("U","e").replace("w","u").replace("g","n").replace("H","n").lower()
print(phrase)
# Out:
# ah mais vous savez, je ne pense pas qu'il y ai de bonnes ou de mauvaises situations.

# %% [markdown]
# Bravo ! Tu vas pouvoir passer à la prochaine quête.
# Tu remarqueras qu'à partir de la prochaîne quête, les consignes sont en **anglais**.
# En effet, pendant la formation, tu vas vite te rendre compte que tout ce qui tourne autour de la data est en anglais (documentation, vocabulaire technique...).
# Alors oui, il est important, lorsqu'on apprend des notions complexes (comme c'est le cas avec Python), de le faire avec sa langue natale pour bien comprendre. C'est exactement pour cette raison que jusqu'à maintenant, les consignes pour les quêtes Python étaient en français.
# Désormais, tu vas apprendre à pratiquer de plus en plus avec la langue anglaise pour être à l'aise lorsque tu seras en entreprise.
# Bon courage !!!
# Si tu as encore trop de mal, tu peux traduire les consignes en français pour t'aider, mais nous t'incitons à faire l'effort de poursuivre en anglais.
