# %% [markdown]
# # Mission 1

# %% [markdown]
# For each cell, execute the code and answer the question before moving on to the next.

# %%
names = ["Fredy", "Nicolas", "Alexandre"]

for i in enumerate(names):
  print(i)
#   print(type(i))
print('i est du type tuple')
# Out:
# (0, 'Fredy')
# (1, 'Nicolas')
# (2, 'Alexandre')
# i est du type tuple

# %% [markdown]
# 1. What type of object is returned as output?
# Hint: You can use `type(i)`.

# %% [markdown]
# Answer:  on obtient un tuple

# %%
for i, val in enumerate(names):
  print(i)
  # print(type(i))
print('i est du type integer')
# Out:
# 0
# 1
# 2
# i est du type integer

# %%
for i, val in enumerate(names):
  print(val)
  # print(type(val))
print("""val est du type string

i correspond à l'index et
val correspond à la valeur
""")
# Out:
# Fredy
# Nicolas
# Alexandre
# val est du type string
#
# i correspond à la clé et
# val correspond à la valeur

# %% [markdown]
# 2. What does `i` correspond to?
# What does `val` correspond to?
# Why is it so?

# %% [markdown]
# Answer:i correspond à la clé et
# val correspond à la valeur

# %%
for val, i in enumerate(names):
  print(i)
  print(type(i))
print('i est du type string')
# Out:
# Fredy
# <class 'str'>
# Nicolas
# <class 'str'>
# Alexandre
# <class 'str'>
# i est du type integer

# %%
for val, i in enumerate(names):
  print(val)
  print(type(val))
print("""val est du type integer
cette fois on trouve l'inverse:
val correspond à l'index' et
i correspond à la valeur
""")
# Out:
# 0
# <class 'int'>
# 1
# <class 'int'>
# 2
# <class 'int'>
# val est du type string
#
# i correspond à la clé et
# val correspond à la valeur

# %% [markdown]
# 3. This time, `i` returns first names and `val` returns numbers. Why is it so?

# %% [markdown]
# Answer:
# Cette fois on trouve l'inverse:
# val correspond à la clé et
# i correspond à la valeur

# %% [markdown]
# 4. What does the built in function `enumerate` do?
# In what cases can it be useful?

# %% [markdown]
# Answer:
#
# On utilise l'enumerate quand on besoin de connaitre la position d'un objet dans une liste

# %% [markdown]
# # Mission 2

# %%
test_list = ['Hi', 'my', 'name', 'is', "hi", "my","name", "is", "chickychicky"]

test_list[8] = "Marshall"

test_list
# Out:
# ['Hi', 'my', 'name', 'is', 'hi', 'my', 'name', 'is', 'Marshall']

# %% [markdown]
# 1. What does the 8 in square brackets mean?
# What action has been performed?

# %% [markdown]
# Answer:
# cela veut dire que l'on selectionne l'objet index 8 donc le 9 éme

# %%
for i in range(4):
  print(test_list[i])
# Out:
# Hi
# my
# name
# is

# %% [markdown]
# 2. What does `range(4)` mean?
# Why are only the first 4 elements of `test_list` displayed?

# %% [markdown]
# Answer:
#
# on fait une boucle de 4 elements de 0 à 3
# ensuite on prend les 4 premiers objets de test_list

# %%
for i in range(2,8,2):
  print(test_list[i])
# Out:
# name
# hi
# name

# %% [markdown]
# 3. What does `range(2,8,2)` mean ?
# Why are only the elements 'name', 'hi' and 'name' displayed?

# %% [markdown]
# Answer:
#
# dans cet exemple on fait une boucle de 2 à 8 exclus avec un pas de 2 donc sur cette liste:
#
#  ['Hi', 'my', 'name', 'is', "hi", "my","name", "is", "chickychicky"]
# on prend :
#
#  ~~'Hi', 'my', ~~'name', ~~~'is',~~ "hi", ~~"my",~~"name", ~~"is",~~ "chickychicky"

# %% [markdown]
# # Mission 3

# %%
numbers = [2,3,1,5,9]

for i in range(10,15):
  numbers.append(i)

numbers
# Out:
# [2, 3, 1, 5, 9, 10, 11, 12, 13, 14]

# %% [markdown]
# 1. What does `range(10,15)` mean ?
#   What is the purpose of the method `append()` ?

# %% [markdown]
# Answer:
#
# on fait une boucle de 10 inclus à  15  exclus.
# dans notre cas le but est de rajouter des elements dans notre liste
#
# append(i) rajoute à la liste numbers l'element à l'index i de la liste numbers

# %%
del numbers[0]

numbers
# Out:
# [3, 1, 5, 9, 10, 11, 12, 13, 14]

# %% [markdown]
# 2. What is the purpose of the `del` command?

# %% [markdown]
# Answer:
#
# del va supprimer des entrées, ici on supprime le premier element donc celui qui se trouve à l'index [0]

# %% [markdown]
# # Mission 4

# %%
import random

random.randint(0,10)
# Out:
# 5

# %% [markdown]
# 1. What can the method `randint()` do ?

# %% [markdown]
# Answer:
#
# random crée un chiffre aléatoire, avec randint(0.10) on crée un entier aléatoire entre 0 et 10 exclus

# %%
numbers.insert(5, "hey hey hey")
numbers
# Out:
# [3, 1, 5, 9, 10, 'hey hey hey', 11, 12, 13, 14]

# %% [markdown]
# 2. What can the method `.insert()` do ?
# You must answer using the terms 'parameter' and 'argument'.

# %% [markdown]
# Answer:
#
# .insert() insére une entrée dans une liste à l'index donné, ici à l'index 5 on rajoute le string "hey hey hey"

# %% [markdown]
# # Mission 5

# %%
test_list = ['Hi', 'my', 'name', 'is', "hi", "my","name", "is", "chickychicky"]
# print(type(test_list))
test_list = " ".join(test_list)
# print(type(test_list))
test_list
# Out:
# 'Hi my name is hi my name is chickychicky'

# %% [markdown]
# 1. What can the `.join()` method do?
# What is the type of `test_list` before using `.join()`?
# What is the type of `test_list` after using `.join()`?

# %% [markdown]
# Answer:
#
# .join() transforme une liste en une chaine de caractére
#
# avant la concaténation test_list était une liste
#
# apres le join il devient un string
#
# on rajoute " ". pour inserer un espace entre chaque valeurs

# %%
christmas = "Noël c'est bien, mais attention à ne pas manger trop de chocolat. On le sait, mais on le fais à chaque fois. C'est la vie"
# print(type(christmas))
christmas.split()
# print(type(christmas.split()))
print(christmas.split())
# Out:
# <class 'str'>
# <class 'list'>
# ['Noël', "c'est", 'bien,', 'mais', 'attention', 'à', 'ne', 'pas', 'manger', 'trop', 'de', 'chocolat.', 'On', 'le', 'sait,', 'mais', 'on', 'le', 'fais', 'à', 'chaque', 'fois.', "C'est", 'la', 'vie']

# %% [markdown]
# 2. What can the `.split()` method do?
# What is the type of `christmas` before using `.split()`?
# What is the type of `christmas` after using `.split()`?

# %% [markdown]
# Answer:
#
# par défaut .split coupe une chaine de caractere en fonction des caracteres
#
#  qu'on lui fournit. Sans rien specifier il prend un espace mais on aurait trés
#
#  bien pu le faire sur les ; en faisant .split(';')
#
#  avant le split on avait un string, aprés le split on obtient une liste

# %%
christmas = "Noël c'est bien, mais attention à ne pas manger trop de chocolat. On le sait, mais on le fais à chaque fois. C'est la vie"


christmas.split("à")
# Out:
# ["Noël c'est bien, mais attention ",
#  ' ne pas manger trop de chocolat. On le sait, mais on le fais ',
#  " chaque fois. C'est la vie"]

# %% [markdown]
# 3. Why does the `.split()` method split the `string` into 3 elements?

# %% [markdown]
# Answer:
#
# comme précisé plus haut ici on split sur le caractétre "à"
