# %% [markdown]
# # Mission 1

# %% [markdown]
# Create a function that returns the sum of 3 + 3 when executed.
# You must use the `return` statement.

# %%
def sum_sun():
  return 3+3

sum_sun()
# Out:
# 6

# %% [markdown]
# # Mission 2

# %% [markdown]
# Create a function that returns the sum of two numbers.
# The user of the function must be able to sum two numbers of his choice, when the function is executed.
# You must not use `input`.

# %%
def sum_two_number(number1, number2):
   return number1 + number2

# test de la fonction
sum_two_number (15,23)
# Out:
# 38

# %% [markdown]
# Question:
# What is a parameter in a function?

# %% [markdown]
# Answer:
#
# des données extérieures que l'on passe en argument de la fonction

# %% [markdown]
# # Mission 3

# %% [markdown]
# Create a function that returns the sum of two numbers chosen by the user of the function, in a sentence.
# For example:
# `new_sum_2(3,8)` returns `"The sum of 3 + 8 is equal to 11."`

# %%
def sum_two_number_bis(number1, number2):
   resultat=print(f"the sum of {number1} + {number2} is equal to {number1 + number2} ")
   return

# test de la fonction
sum_two_number_bis (15,23)
# Out:
# the sum of 15 + 23 is equal to 38

# %% [markdown]
# # Mission 4
#
# Create a function that returns 2 objects when executed:
# * An object that will be the product of two numbers chosen by the user of the function.
# * A word chosen by the user of the function.

# %%
def product_two_number(number1, number2,your_word):
   resultat=number1 * number2
   print(f"the product of {number1} * {number2} is equal to {resultat} ")
   message=your_word
   return resultat,message

# test de la fonction
product_two_number (15,23,"hello Tonton!")
# Out:
# the product of 15 * 23 is equal to 345
# (345, 'hello Tonton!')

# %% [markdown]
# Your result must be two objects that are in brackets.
# This is a tuple.
#
# Question:
# Why is the returned object a tuple that contains two objects?
#
# Answer:
#
# because a tuple is built when functions are returning multiple item objects separated by a comma. et
#
# parce que c'est comme ca!!!

# %% [markdown]
# # Mission 5
#
# Create a function that returns the sum of two numbers when executed.
# Also, your function must return a sentence that simply indicates if the sum of the two numbers chosen by the user is:
# * less than 10
# * between 10 and 50
# * greater than 50
# Again, you must use `return`.

# %%
import random

def sum_two_number_ter(number1, number2):
   resultat=number1 + number2
   print(f"the sum of {number1} + {number2} is equal to {resultat} ")
   if resultat<10: return (f"your result {resultat} is less than 10")
   elif resultat >= 10 and resultat <= 50: return(f"your result {resultat} is between 10 and 50")
   else:return(f"your result {resultat} is greater than 50")


# test de la fonction
first_number=random.randint(1,30) # creation d'un chiffre aleatoire entre 1 et 30
second_number=random.randint(1,20)
sum_two_number_ter (first_number,second_number)
# Out:
# the sum of 13 + 10 is equal to 23
# 'your result 23 is between 10 and 50'
