# %%
# Library / Module importation
from google.colab import files
# Variable creation "uploaded", that will contain your module.
# You can name this variable as you prefer.
uploaded = files.upload()
# It's as simple as an "input()"
# Out:
#      <input type="file" id="files-830e20a1-3dff-4bb8-a27e-145c0fad67ff" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-830e20a1-3dff-4bb8-a27e-145c0fad67ff">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import my_math_functions as my
import random
#   variables
nombre1 = random.randint(-10, 50)
# nombre2 = 3
list_of_number = [random.randint(0, 50) for v in range(10)]


# # test fonctions
# print(my.calculate_square(nombre1))
# print(my.calculate_cube(nombre1))
# print(my.get_absolute_value(nombre1))
# print(my.factorielle_number(nombre1))

# # test fonctions list
# print("\n\n", list_of_number)

# print(my.mode_of_list(list_of_number))
# print(my.average_list(list_of_number))
# print(my.minimum_of_list(list_of_number))
# print(my.maximum_of_list(list_of_number))


resultat = my.calculate_square(42)+my.calculate_cube(3)+my.factorielle_number(
    5)/my.get_absolute_value(-15)-my.maximum_of_list(list_of_number)*my.minimum_of_list(list_of_number)

texte="(carré de 42) + (3 au cube) + (factorielle de 5) /divisé par la (valeur absolue de (-15) ) - (maximum d'une liste de int (à créer) ) * (minimum de la liste)"

# %% [markdown]
# ### Le resultat de l'équation :
# (carré de 42) + (3 au cube) + (factorielle de 5) /divisé par la (valeur absolue de (-15) ) - (maximum d'une liste de int (à créer) ) * (minimum de la liste)
#
# ### est :

# %%
print("résultat:", resultat)
# Out:
# résultat: 1615.0

# %% [markdown]
# ## AUTRE SOLUTION AVEC IMPORT DU MODULE DEPUIS GITHUB

# %%
import requests      # La librairie requests permet d'effectuer des requêtes HTTP sur Python

# f = open("module_t.py", "a")
f = open("my_file_to_import_module.py", "a")
# Fonction open(), ici on va vouloir ouvrir le fichier module.py
# Ici mode "a" = for appending at the end of the file without truncating it. Creates a new file if it does not exist.
# my_file_to_import_module.py n'existant pas, il va être créé

# f.write(requests.get("https://raw.githubusercontent.com/PaulGRAUWIN/Module1/main/modulePG.py.txt").text)
f.write(requests.get("https://raw.githubusercontent.com/bigmoletos/WildCodeSchool_formation_IA_nov2023/dev1/qu%C3%AAtes/Semaine4/my_math_functions.py").text)
# La fonction .get permet de récupérer les informations d'une source définie, ici une page github
#La méthode .text permet d'en extraire le texte
#La méthode write va écrire dans le fichier "my_file_to_import_module.py" le contenu extrait
# f est de type : <class '_io.TextIOWrapper'>

f.close()
#Fermeture du fichier module.py relié à f

# %%
from my_math_functions import *
#Importation de l'ensemble des fonctions de module1

# %%
resultat = my.calculate_square(42)+my.calculate_cube(3)+my.factorielle_number(
    5)/my.get_absolute_value(-15)-my.maximum_of_list(list_of_number)*my.minimum_of_list(list_of_number)

texte="(carré de 42) + (3 au cube) + (factorielle de 5) /divisé par la (valeur absolue de (-15) ) - (maximum d'une liste de int (à créer) ) * (minimum de la liste)"

print("résultat:", resultat)
# Out:
# résultat: 1615.0
